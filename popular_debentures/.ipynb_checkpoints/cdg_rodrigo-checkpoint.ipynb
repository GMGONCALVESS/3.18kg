# %%
import requests
import base64
from base64 import b64encode
import json
import pandas as pd
from sqlalchemy import create_engine, MetaData, Table
# import psycopg2

# Substitua pelos seus client_id e client_secret fornecidos pela ANBIMA
client_id = 'uHpXjsZAi49A'
client_secret = '2tZrvxqLYZ1N'

# Cria a string "{client_id}:{client_secret}" e a codifica em base64
auth_string = f"{client_id}:{client_secret}"
auth_bytes = auth_string.encode("ascii")
auth = base64.b64encode(auth_bytes).decode("ascii")


# Cabeçalhos da requisição de autenticação
auth_headers = {
    'Content-Type': 'application/x-www-form-urlencoded',
    'Authorization': f'Basic {auth}'
    }

# Corpo da requisição de autenticação
auth_data = {
    'grant_type': 'client_credentials'
}

# URL de autenticação da ANBIMA
auth_url = 'https://api.anbima.com.br/oauth/access-token'

# Fazer a requisição POST para obter o token
auth_response = requests.post(auth_url, headers=auth_headers, data=auth_data)

# Obter o token de acesso
access_token = auth_response.json().get('access_token')
# Cabeçalhos para a requisição de dados usando o token
headers = {
            'access_token': access_token,
          'client_id' : client_id
}

# URL do endpoint de títulos públicos
data_url = 'https://api.anbima.com.br/feed/precos-indices/v1/titulos-publicos/mercado-secundario-TPF'
# Fazer a requisição GET para obter os dados
data_response = requests.get(data_url, headers=headers)
# Verificar se a requisição foi bem-sucedida
if data_response.status_code == 200:
    # Exibir os dados obtidos
    data = data_response.json()
else:
    print(f"Erro ao obter os dados: {data_response.status_code} - {data_response.text}")

df_TPF = pd.DataFrame(data)
df_TPF.rename(columns={'index': 'indexador'}, inplace=True)

# URL do endpoint de CRI e CRA
data_url = 'https://api.anbima.com.br/feed/precos-indices/v1/cri-cra/mercado-secundario'
# Fazer a requisição GET para obter os dados
data_response = requests.get(data_url, headers=headers)
# Verificar se a requisição foi bem-sucedida
if data_response.status_code == 200:
    # Exibir os dados obtidos
    data = data_response.json()
else:
    print(f"Erro ao obter os dados: {data_response.status_code} - {data_response.text}")

df_CRICRA = pd.DataFrame(data)

# URL do endpoint de Debentures
data_url = 'https://api.anbima.com.br/feed/precos-indices/v1/debentures/mercado-secundario'
# Fazer a requisição GET para obter os dados
data_response = requests.get(data_url, headers=headers)
# Verificar se a requisição foi bem-sucedida
if data_response.status_code == 200:
    # Exibir os dados obtidos
    data = data_response.json()
else:
    print(f"Erro ao obter os dados: {data_response.status_code} - {data_response.text}")

df_debentures = pd.DataFrame(data)

# URL do endpoint de SELIC
data_url = 'https://api.anbima.com.br/feed/precos-indices/v1/titulos-publicos/estimativa-selic'
# Fazer a requisição GET para obter os dados
data_response = requests.get(data_url, headers=headers)
# Verificar se a requisição foi bem-sucedida
if data_response.status_code == 200:
    # Exibir os dados obtidos
    data = data_response.json()
else:
    print(f"Erro ao obter os dados: {data_response.status_code} - {data_response.text}")

df_selic = pd.DataFrame(data)

# URL do endpoint de vna
data_url = 'https://api.anbima.com.br/feed/precos-indices/v1/titulos-publicos/vna'
# Fazer a requisição GET para obter os dados
data_response = requests.get(data_url, headers=headers)
# Verificar se a requisição foi bem-sucedida
if data_response.status_code == 200:
    # Exibir os dados obtidos
    data = data_response.json()
else:
    print(f"Erro ao obter os dados: {data_response.status_code} - {data_response.text}")

df_vna = pd.json_normalize(data, 'titulos', ['data_referencia'])


# # Configurando a conexão com o banco de dados
# engine = create_engine('postgresql://postgres:admin@192.168.88.61:5432/dimensa')
# metadata = MetaData()

# # Inicializando a tabela e inserindo os dados
# table_titulospublicos = Table('titulos_publicos', metadata, autoload_with=engine)
# table_cri_cra = Table('cri_cra', metadata, autoload_with=engine)
# table_debentures = Table('debentures', metadata, autoload_with=engine)
# table_selic = Table('selic_estimativa', metadata, autoload_with=engine)
# table_vna = Table('vna', metadata, autoload_with=engine)


# df_TPF.to_sql(
#     name="titulos_publicos",
#     con=engine,
#     if_exists="append",
#     index=False)

# df_CRICRA.to_sql(
#     name="cri_cra",
#     con=engine,
#     if_exists="append",
#     index=False)

# df_debentures.to_sql(
#     name="debentures",
#     con=engine,
#     if_exists="append",
#     index=False)

# df_selic.to_sql(
#     name="selic_estimativa",
#     con=engine,
#     if_exists="append",
#     index=False)

# df_vna.to_sql(
#     name="vna",
#     con=engine,
#     if_exists="append",
#     index=False)

# %%
print(auth_response.json())
# Out:
# {'access_token': '99zI5zd2FK2R', 'token_type': 'access_token', 'expires_in': 3600}
