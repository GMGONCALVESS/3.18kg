# %%
import requests
import base64
from base64 import b64encode
import json
import pandas as pd

client_id = 'uHpXjsZAi49A'
client_secret = '2tZrvxqLYZ1N'

auth_string = f"{client_id}:{client_secret}"
auth_bytes = auth_string.encode("ascii")
auth = base64.b64encode(auth_bytes).decode("ascii")

auth_headers = {
    'Content-Type': 'application/x-www-form-urlencoded',
    'Authorization': f'Basic {auth}'
    }

# Corpo da requisição de autenticação
auth_data = {
    'grant_type': 'client_credentials'
}

auth_url = 'https://api.anbima.com.br/oauth/access-token'

auth_response = requests.post(auth_url, headers=auth_headers, data=auth_data)

access_token = auth_response.json().get('access_token')

headers = {
            'access_token': access_token,
          'client_id' : client_id
}

parameters = {
    'data': '2018-01-02'
}

data_url = 'https://api.anbima.com.br/feed/precos-indices/v1/titulos-publicos/curvas-juros'

data_response = requests.get(data_url, headers=headers, params=parameters)

if data_response.status_code == 200:
    data = data_response.json()
else:
    print(f"Erro ao obter os dados: {data_response.status_code} - {data_response.text}")

# %%
print(data)
print(data[0].keys())

print(data[0]["data_referencia"])
# print(data[0]["data_referencia"])
#print(data[0].values()[0])
# Out:
# [{'data_referencia': '2018-01-05', 'parametros': [{'grupo_indexador': 'IPCA', 'b1': 0.0563950576605931, 'b2': 0.0411916177768795, 'b3': -0.2004816192708211, 'b4': 0.0350973507846759, 'l1': 2.0837444672350496, 'l2': 1.1479001034616436}, {'grupo_indexador': 'PREFIXADOS', 'b1': 0.1129562539979033, 'b2': -0.0376898150856504, 'b3': -0.0898234383362505, 'b4': -0.0052736535906101, 'l1': 1.7983750303549213, 'l2': 0.3598616796271131}], 'erros': [{'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2018-04-01', 'valor_erro': 0.0637}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2018-07-01', 'valor_erro': -0.096}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2018-10-01', 'valor_erro': -0.072}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2019-01-01', 'valor_erro': 0.0449}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2019-04-01', 'valor_erro': 0.0585}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2019-07-01', 'valor_erro': 0.065}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2019-10-01', 'valor_erro': -0.0159}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2020-01-01', 'valor_erro': -0.0121}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2020-04-01', 'valor_erro': -0.0514}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2020-07-01', 'valor_erro': -0.0561}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2021-07-01', 'valor_erro': -0.0434}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2022-01-01', 'valor_erro': -0.0318}, {'tipo_titulo': '760100', 'codigo_selic': 'NTN-B', 'data_vencimento': '2023-03-15', 'valor_erro': -0.0616}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2018-08-15', 'valor_erro': -0.0095}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2019-05-15', 'valor_erro': 0.0256}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2020-08-15', 'valor_erro': -0.0496}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2021-05-15', 'valor_erro': 0.0241}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2022-08-15', 'valor_erro': 0.047}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2023-05-15', 'valor_erro': -0.0393}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2024-08-15', 'valor_erro': 0.0133}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2026-08-15', 'valor_erro': 0.0692}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2030-08-15', 'valor_erro': -0.0037}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2035-05-15', 'valor_erro': -0.0102}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2040-08-15', 'valor_erro': 0.0218}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2045-05-15', 'valor_erro': -0.0349}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2050-08-15', 'valor_erro': -0.0169}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2055-05-15', 'valor_erro': 0.0218}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2019-01-01', 'valor_erro': 0.0145}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2021-01-01', 'valor_erro': 0.0302}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2023-01-01', 'valor_erro': 0.0276}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2025-01-01', 'valor_erro': 0.0109}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2027-01-01', 'valor_erro': 0.0109}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2029-01-01', 'valor_erro': -0.0133}], 'ettj': [{'vertice_du': 252, 'taxa_pre ...
# dict_keys(['data_referencia', 'parametros', 'erros', 'ettj', 'bloco3361'])
# 2018-01-05

# %%
from collections import Counter

codigos = [d['codigo_ativo'] for d in data]
contador = Counter(codigos)

# Passo 2: Identificar os códigos repetidos
codigos_repetidos = {codigo for codigo, count in contador.items() if count > 1}

# Passo 3: Filtrar os dicionários que possuem `codigo_ativo` repetido
dicionarios_repetidos = [d for d in data if d['codigo_ativo'] in codigos_repetidos]

# Exibir os resultados
print("Códigos repetidos:", codigos_repetidos)
print("Dicionários com códigos repetidos:")
for d in dicionarios_repetidos:
    print(d)
# Out:
# Códigos repetidos: set()
# Dicionários com códigos repetidos:

# %% [markdown]
# # Não existem códigos repetidos

# %%
pd.set_option('display.max_rows', None)
df = pd.DataFrame(data)
# df
df[df['grupo'].str.contains('DI')]
# Out:
#               grupo codigo_ativo data_referencia data_vencimento  \
# 0         DI SPREAD       AALM12      2025-01-29      2030-10-02
# 1         DI SPREAD       AALR13      2025-01-29      2027-10-04
# 4         DI SPREAD       AEGE16      2025-01-29      2034-03-11
# 5         DI SPREAD       AEGE17      2025-01-29      2035-06-15
# 6         DI SPREAD       AEGP14      2025-01-29      2025-02-05
# 7         DI SPREAD       AEGP17      2025-01-29      2027-04-12
# 8         DI SPREAD       AEGP19      2025-01-29      2028-10-04
# 10        DI SPREAD       AEGPA1      2025-01-29      2029-09-02
# 11        DI SPREAD       AEGPA3      2025-01-29      2026-03-15
# 12        DI SPREAD       AEGPA4      2025-01-29      2028-10-25
# 13        DI SPREAD       AEGPA7      2025-01-29      2026-09-15
# 14        DI SPREAD       AEGPA9      2025-01-29      2029-06-25
# 15        DI SPREAD       AEGPB7      2025-01-29      2028-09-15
# 16        DI SPREAD       AERI11      2025-01-29      2026-01-15
# 17        DI SPREAD       AERI12      2025-01-29      2026-07-31
# 23        DI SPREAD       AETE11      2025-01-29      2026-09-10
# 24        DI SPREAD       AGAU13      2025-01-29      2027-03-15
# 28        DI SPREAD       ALGA28      2025-01-29      2026-02-15
# 29        DI SPREAD       ALGAA1      2025-01-29      2028-07-15
# 30        DI SPREAD       ALGAA2      2025-01-29      2029-01-15
# 34        DI SPREAD       ALGTA3      2025-01-29      2027-02-17
# 39        DI SPREAD       ALMC12      2025-01-29      2027-06-10
# 40        DI SPREAD       ALPA12      2025-01-29      2025-01-30
# 41        DI SPREAD       ALSO15      2025-01-29      2027-03-15
# 42        DI SPREAD       ALSO25      2025-01-29      2029-03-15
# 43        DI SPREAD       ALSR12      2025-01-29      2025-03-15
# 44        DI SPREAD       ALTF11      2025-01-29      2027-01-15
# 46        DI SPREAD       AMBP16      2025-01-29      2029-04-25
# 49        DI SPREAD       ANHBA4      2025-01-29      2028-06-14
# 50        DI SPREAD       ANHBA5      2025-01-29      2030-11-05
# 53        DI SPREAD       APPSB2      2025-01-29      2028-09-15
# 55        DI SPREAD       APRB28      2025-01-29      2027-06-15
# 56        DI SPREAD       ARML13      2025-01-29      2029-11-04
# 57        DI SPREAD       ARML14      2025-01-29      2032-03-15
# 58        DI SPREAD       ARML15      2025-01-29      2032-09-25
# 59        DI SPREAD       ARML25      2025-01-29      2034-09-25
# 61        DI SPREAD       ARTRA1      2025-01-29      2027-03-11
# 62        DI SPREAD       ARTRA4      2025-01-29      2028-08-24
# 63        DI SPREAD       ARTRA5      2025-01-29      2029-04-12
# 65        DI SPREAD       ASAI14      2025-01-29      2027-11-26
# 66        DI SPREAD       ASAI18      2025-01-29      2027-12-22
# 1022      DI SPREAD       VBBR26      2025-01-29      2034-04-05
# 1026      DI SPREAD       VECS11      2025-01-29      2025-07-18
# 1031      DI SPREAD       VIXL14      2025-01-29      2026-03-15
# 1032      DI SPREAD       VIXL15      2025-01-29      2026-10-26
# 1033      DI SPREAD       VIXL18      2025-01-29      2030-06-11
# 1034      DI SPREAD       VIXL25      2025-01-29      2028-10-26
# 1035      DI SPREAD       VIXL26      2025-01-29      2028-09-29
# 1036      DI SPREAD       VIXL35      2025-01-29      2026-10-26
# 1037      DI SPREAD       VIXL45      2025-01-29      2028-10-26
# 1038      DI SPREAD       VLID19      2025-01-29      2027-06-20
# 1043      DI SPREAD       VLME11      2025-01-29      2027-11-16
# 1044      DI SPREAD       VLME12      2025-01-29      2028-08-15
# 1047      DI SPREAD       VVEO15      2025-01-29      2027-07-22
# 1048      DI SPREAD       VVEO16      2025-01-29      2027-10-27
# 1050      DI SPREAD       WIZS11      2025-01-29      2026-08-18
# 1052      DI SPREAD       XPVS24      2025-01-29      2025-06-23
# 1053      DI SPREAD       XVII11      2025-01-29      2025-06-28
# 1054      DI SPREAD       YDUQ18      2025-01-29      2027-09-23
# 1055      DI SPREAD       YDUQA0      2025-01-29      2029-04-10
#
#       percentual_taxa  taxa_compra  taxa_venda  taxa_indicativa  \
# 0        DI + 1,6000%       1.5619      1.3318           1.4418
# 1        DI + 2,7500%      15.2390      8.4987          12.4323
# 4        DI + 3,9000%       3.4500      3.0197           3.2308
# 5        DI + 3,4000%       3.8000      3.3000           3.5509
# 6        DI + 1,8000%       0.9819      0.2132           0.6670
# 7        DI + 2,1500%       1.5557      1.3500           1.4559
# 8        DI + 1,9000%       2.0621      1.6145           1.8406
# 10       DI + 2,4500%       2.3500      1.9884           2.1802
# 11       DI + 3,0000%       2.4698      2.2000           2.3394
# 12       DI + 3,4700%       2.4024      2.2000           2.3002
# 13       DI + 2,7500%       2.2141      1.9000           2.0507
# 14       DI + 2,7500%       2.3539      1.9934           2.1538
# 15       DI + 2,9500%       2.3548      1.9981           2.1863
# 16       DI + 2,9000%          NaN         NaN              NaN
# 17       DI + 2,0000%          NaN         NaN              NaN
# 23       DI + 2,7000%       2.2631      1.5000           1.9000
# 24       DI + 4,5000%       4.1167      3.1144           3.6216
# 28       DI + 0,9000%       1.1299      0.7625           0.9787
# 29       DI + 1,6000%       1.6153      1.2452           1.4183
# 30       DI + 1,5500%       1.5946      1.2665           1.4488
# 34       DI + 2,0000%       1.6510      1.2110           1.4495
# 39       DI + 4,8000%       5.9081      4.6929           5.1506
# 40       DI + 1,3500%       1.1590      0.7996           1.0005
# 41       DI + 1,4300%       0.9710      0.6875           0.8331
# 42       DI + 1,5500%       1.0882      0.8202           0.9726
# 43       DI + 2,3500%       3.3375      1.8601           2.6232
# 44       DI + 2,3000%       2.3726      1.9059           2.1439
# 46       DI + 2,7500%       3.4850      2.6365           3.0675
# 49       DI + 2,1400%       1.4079      1.2018           1.3186
# 50       DI + 0,4400%       0.8956      0.7000           0.8101
# 53       DI + 2,1500%       1.9142      1.5953           1.7605
# 55       DI + 0,8600%       1.0630      0.6496           0.8513
# 56       DI + 2,2500%       1.8545      1.4500           1.6754
# 57       DI + 1,9000%       1.9144      1.5019           1.7369
# 58       DI + 1,3500%       2.7178      1.6082           2.1331
# 59       DI + 1,6000%       2.3901      1.7940           1.9734
# 61       DI + 1,6500%       1.7008      1.2824           1.5011
# 62       DI + 2,7000%       2.2189      1.8640           2.0150
# 63       DI + 2,4000%       2.3623      1.9690           2.1606
# 65       DI + 1,7500%       1.9444      1.6764           1.8139
# 66       DI + 1,8500%       2.2610      1.2350           1.7379
# 67       DI + 1,2500%       2.2787      1.8162           2.0995
# 68       DI + 1,9500%       2.0122      1.7197           1.8850
# 69       DI + 1,9500%       2.0747      1.7984           1.9120
# 70       DI + 1,2500%       2.0586      1.7639           1.9158
# 71       DI + 1,2500%       2.0970      1.7714           1.9206
# 79       DI + 0,5500%       1.1481      0.7667           0.9506
# 80       DI + 1,1000%       1.2241      0.8662           1.0627
# 82       DI + 2,6500%       2.1307      1.7683           1.9924
# 83       DI + 1,4500%       1.3005      1.1898           1.2477
# 84       DI + 1,3500%          NaN         NaN           0.8927
# 85       DI + 1,2000%       1.0545      0.7234           0.8166
# 88       DI + 1,9000%       2.9394      2.2933           2.5827
# 91       DI + 2,0000%       1.4677      0.8641           1.2147
# 92       DI + 1,6000%       1.6820      1.2575           1.4745
# 93       DI + 1,7500%       3.3770      3.0000           3.2108
# 94       DI + 1,7000%       3.3807      3.0000           3.2465
# 95       DI + 2,0000%       3.3546      2.4851           2.9374
# 96       DI + 1,9500%       3.5472      3.1676           3.3605
# 98       DI + 2,4000%       2.3627      2.0105           2.1857
# 99       DI + 3,4000%       2.4570      2.1406           2.2966
# 100      DI + 3,2500%       2.5997      2.1935           2.4405
# 101      DI + 2,9300%       2.6365      2.3522           2.4945
# 102      DI + 0,6300%       0.9534      0.6671           0.7531
# 103      DI + 0,9500%       1.0708      0.8716           0.9603
# 105      DI + 1,0500%       1.1029      0.4605           0.8499
# 106      DI + 1,0500%       0.9562      0.6822           0.7929
# 107      DI + 0,6200%       0.8000      0.5535           0.6661
# 108      DI + 4,5000%       4.0000      3.5000           3.7812
# 109      DI + 3,5000%       3.7045      3.2988           3.4875
# 110      DI + 1,5000%       1.5791      1.3000           1.4126
# 111      DI + 4,5000%       3.7379      3.3930           3.5632
# 112      DI + 2,1000%       1.5984      1.1097           1.3808
# 115      DI + 2,2000%       2.0790      1.5905           1.8408
# 116      DI + 2,5000%       2.2391      1.7718           2.0310
# 119      DI + 2,7000%       1.2986      0.9203           1.1060
# 120      DI + 1,5500%       1.8573      1.5323           1.7202
# 121      DI + 1,5500%       1.8524      1.4134           1.6360
# 123      DI + 5,7500%       1.5000      0.4995           1.0041
# 124      DI + 5,5000%       2.7530      1.8343           2.2681
# 127      DI + 2,0000%       1.0274      0.6643           0.8526
# 131      DI + 1,7000%       9.2500      6.9731           8.0281
# 132      DI + 1,9500%      13.0069      8.8398          11.1386
# 135      DI + 0,7500%       0.7782      0.6317           0.7055
# 138      DI + 2,0000%       2.8788      2.3496           2.6165
# 140      DI + 2,1500%       1.0000      0.2398           0.6430
# 141      DI + 2,1000%       1.8500      1.4810           1.6792
# 142      DI + 1,8000%       2.1051      1.7474           1.9392
# 143      DI + 2,4000%       2.0007      1.6303           1.8405
# 150      DI + 1,3400%       1.1500      0.8000           0.9821
# 151      DI + 1,9500%       1.5011      1.2000           1.3860
# 152      DI + 1,1800%       1.1000      0.8000           0.9525
# 153      DI + 0,9500%       0.9169      0.6480           0.7842
# 154   110,2500% do DI     107.9880    103.8650         106.0708
# 155      DI + 1,4900%       1.1000      0.6000           0.8910
# 158      DI + 1,1000%       1.1000      0.7000           0.9214
# 161      DI + 1,4500%       1.0481      0.8000           0.9534
# 164      DI + 1,6500%       1.1969      0.7643           0.9764
# 166      DI + 1,0500%       1.1457      0.8803           1.0069
# 169      DI + 1,4000%       1.1000      0.7071           0.9315
# 170      DI + 1,2000%       0.7100      0.3063           0.5380
# 172      DI + 1,0500%       0.8430      0.5782           0.7094
# 174   111,0000% do DI     108.2630    102.9566         105.3727
# 175      DI + 1,3900%       1.1500      0.8088           1.0110
# 176      DI + 1,1800%       1.1492      0.9000           1.0514
# 177      DI + 1,1800%       1.1505      0.9000           1.0280
# 178      DI + 1,5400%       1.3000      0.8382           1.0738
# 179      DI + 1,6800%       1.6288      1.3067           1.4568
# 183      DI + 0,8500%       0.8068      0.5554           0.7136
# 184      DI + 2,5000%       0.8840      0.6268           0.7039
# 188      DI + 0,8000%       0.9801      0.6873           0.8096
# 192      DI + 2,0000%          NaN         NaN           1.7875
# 193      DI + 2,3500%       2.7574      2.4127           2.6088
# 196      DI + 1,6500%       1.0348      0.6995           0.8839
# 197      DI + 1,0500%       1.0928      0.8086           0.9534
# 199      DI + 1,0000%       1.1419      0.7578           0.9733
# 200      DI + 1,0000%       1.1281      0.8742           0.9983
# 205      DI + 0,8500%       1.2992      0.9074           1.0855
# 206      DI + 1,0500%       1.4324         NaN           1.2065
# 207      DI + 0,5400%       0.6644      0.4744           0.5810
# 210      DI + 2,6000%       1.5818      0.9366           1.3111
# 211      DI + 1,6500%       1.3585         NaN           0.9839
# 212      DI + 0,9500%          NaN      0.6994           0.8489
# 215      DI + 3,5000%       2.2039      1.6724           1.9372
# 219      DI + 1,3500%       1.0500      0.6559           0.8816
# 220      DI + 2,0500%       1.4739      1.1067           1.3276
# 223      DI + 0,8000%       1.0253      0.6416           0.8418
# 224      DI + 0,5500%       1.1603      0.7563           0.9786
# 231      DI + 1,7000%      80.0000     30.0000          54.9996
# 232      DI + 1,3300%       0.9011      0.6012           0.7685
# 236      DI + 1,4800%       1.1849      0.9000           1.0288
# 237      DI + 1,3500%       1.6703      1.2721           1.4370
# 238      DI + 1,6000%          NaN         NaN              NaN
# 239      DI + 1,6000%       1.8234      1.3784           1.5873
# 240      DI + 3,2000%          NaN         NaN           2.7587
# 243      DI + 2,2000%       1.8767      1.4575           1.7039
# 246      DI + 1,9000%       1.6443      1.3508           1.4944
# 248      DI + 0,5900%       1.1500      0.8000           0.9802
# 250      DI + 1,4700%       1.0745      0.7834           0.9540
# 252      DI + 0,5700%       0.9995      0.5619           0.7917
# 256      DI + 1,3800%       1.0500      0.7794           0.9278
# 257      DI + 1,4000%       1.1524      0.7676           0.9673
# 258      DI + 0,5200%       1.1040      0.7854           0.9576
# 262      DI + 0,6900%       1.3374      0.8500           1.0730
# 264      DI + 1,7500%       1.7619      1.2741           1.5431
# 265      DI + 1,2100%       1.0037      0.8239           0.9388
# 266      DI + 0,6000%       1.1874      0.7440           0.9795
# 268      DI + 1,3600%       1.0000      0.5984           0.7932
# 269      DI + 2,0000%       1.3006      1.1319           1.2154
# 272      DI + 2,2500%       1.3891      0.8787           1.1817
# 273      DI + 1,7000%       1.2453      0.8000           1.0383
# 276      DI + 1,2000%       1.2473      0.9944           1.1696
# 277      DI + 1,3500%       1.3500      1.0528           1.2447
# 279      DI + 2,5000%       2.0906      1.1861           1.6220
# 281      DI + 1,6500%       1.4651      1.0779           1.2600
# 282      DI + 1,5000%       1.3514      1.2064           1.2433
# 283      DI + 2,4000%       1.7555      1.4024           1.6094
# 284      DI + 2,4000%       1.8960      1.5596           1.7244
# 285      DI + 1,8000%       1.5905      1.2547           1.4414
# 286      DI + 2,0000%       1.6303      1.3000           1.4632
# 288      DI + 1,0000%       1.4529      1.2196           1.3280
# 289      DI + 0,5000%       1.2344      0.9855           1.1012
# 290      DI + 1,5000%       1.7787      1.4597           1.6086
# 291      DI + 0,7200%       1.5007         NaN           1.3093
# 292      DI + 1,3000%       2.1213      1.6353           1.8453
# 294      DI + 1,7500%       1.0000      0.5116           0.8812
# 296      DI + 1,3000%       0.9042      0.6430           0.8042
# 297      DI + 1,2000%       0.9388         NaN           0.8858
# ...
# 656                             LOCALIZA RENT A CAR (*)             NaN
# 657                        LOCALIZA RENT A CAR (*) (**)             NaN
# 658                             LOCALIZA RENT A CAR (*)             NaN
# 659                             LOCALIZA RENT A CAR (*)             NaN
# 660                             LOCALIZA RENT A CAR (*)             NaN
# 661                             LOCALIZA RENT A CAR (*)             NaN
# 662                           LOJAS RENNER S/A (*) (**)             NaN
# 664   LIVETECH DA BAHIA INDUSTRIA E COMERCIO S/A (*)...             NaN
# 665                         HOSPITAL MATER DEI S.A. (*)             NaN
# 666                         HOSPITAL MATER DEI S.A. (*)             NaN
# 668                              MAGAZINE LUIZA S/A (*)             NaN
# 670        MILLS ESTR. E SERVIÇOS DE ENGENHARIA S/A (*)             NaN
# 672                                           MNLT S.A.             NaN
# 673                                MINERVA S/A (*) (**)             NaN
# 674                        MOVIDA PARTICIPACOES S/A (*)             NaN
# 676                   MOVIDA PARTICIPACOES S/A (*) (**)             NaN
# 677                   MOVIDA PARTICIPACOES S/A (*) (**)             NaN
# 678                   MOVIDA PARTICIPACOES S/A (*) (**)             NaN
# 680                        MOVIDA PARTICIPACOES S/A (*)             NaN
# 681                        MOVIDA PARTICIPACOES S/A (*)             NaN
# 682                  MARFRIG GLOBAL FOODS S.A. (*) (**)             NaN
# 689                          MRS LOGÍSTICA S/A (*) (**)             NaN
# 691          MRV ENGENHARIA E PARTICIPAÇÃO S/A (*) (**)             NaN
# 692          MRV ENGENHARIA E PARTICIPAÇÃO S/A (*) (**)             NaN
# 698             COMPANHIA DO METROPOLITANO DE SAO PAULO             NaN
# 699   MULTIPLAN EMPREENDIMENTOS IMOBILIÁRIOS S/A (*)...             NaN
# 700   MULTIPLAN EMPREENDIMENTOS IMOBILIÁRIOS S/A (*)...             NaN
# 701   MULTIPLAN EMPREENDIMENTOS IMOBILIÁRIOS S/A (*)...             NaN
# 702   MULTIPLAN EMPREENDIMENTOS IMOBILIÁRIOS S/A (*)...             NaN
# 703   MULTIPLAN EMPREENDIMENTOS IMOBILIÁRIOS S/A (*)...             NaN
# 705                 MOVIDA LOCACAO DE VEICULOS S.A. (*)             NaN
# 706                 MOVIDA LOCACAO DE VEICULOS S.A. (*)             NaN
# 707                 MOVIDA LOCACAO DE VEICULOS S.A. (*)             NaN
# 708                           NATURA COSMÉTICOS S/A (*)             NaN
# 711           NOVA TRANSPORTE DO SUDESTE S.A. - NTS (*)             NaN
# 716           NOVA TRANSPORTE DO SUDESTE S.A. - NTS (*)             NaN
# 717           NOVA TRANSPORTE DO SUDESTE S.A. - NTS (*)             NaN
# 718           NOVA TRANSPORTE DO SUDESTE S.A. - NTS (*)             NaN
# 719          NOVA TRANSPORTE DO SUDESTE S.A. - NTS  (*)             NaN
# 720           NOVA TRANSPORTE DO SUDESTE S.A. - NTS (*)             NaN
# 721           NOVA TRANSPORTE DO SUDESTE S.A. - NTS (*)             NaN
# 722           NOVA TRANSPORTE DO SUDESTE S.A. - NTS (*)             NaN
# 725                 OMEGA DESENVOLVIMENTO S.A. (*) (**)             NaN
# 727                               OMEGA GERAÇÃO S/A (*)             NaN
# 728                          OMEGA GERAÇÃO S/A (*) (**)             NaN
# 733   ONCOCLINICAS DO BRASIL SERVICOS MEDICOS S.A. (...             NaN
# 734   ONCOCLINICAS DO BRASIL SERVICOS MEDICOS S.A. (...             NaN
# 735   ONCOCLINICAS DO BRASIL SERVICOS MEDICOS S.A. (...             NaN
# 736               OCEANPACT SERVICOS MARITIMOS S.A. (*)             NaN
# 737               OCEANPACT SERVICOS MARITIMOS S.A. (*)             NaN
# 738               OCEANPACT SERVICOS MARITIMOS S.A. (*)             NaN
# 740                       ORIZON MEIO AMBIENTE S.A. (*)             NaN
# 741            UNIDAS LOCACOES E SERVICOS S.A. (*) (**)             NaN
# 742            UNIDAS LOCACOES E SERVICOS S.A. (*) (**)             NaN
# 743                 UNIDAS LOCACOES E SERVICOS S.A. (*)             NaN
# 744                 UNIDAS LOCACOES E SERVICOS S.A. (*)             NaN
# 745                 UNIDAS LOCACOES E SERVICOS S.A. (*)             NaN
# 747          COMPANHIA PAULISTA DE FORÇA E LUZ (*) (**)             NaN
# 749               COMPANHIA PAULISTA DE FORÇA E LUZ (*)             NaN
# 750               COMPANHIA PAULISTA DE FORÇA E LUZ (*)             NaN
# 753                       COMPASS GAS E ENERGIA S.A (*)             NaN
# 754                       COMPASS GAS E ENERGIA S.A (*)             NaN
# 756                  PETRO RIO JAGUAR PETROLEO S.A. (*)             NaN
# 763        PETRÓLEO BRASILEIRO S/A - PETROBRAS (*) (**)             NaN
# 765                      AUTOPISTA LITORAL SUL S/A. (*)             NaN
# 770       PROLAGOS S/A - C.S.PUBL. DE ÁGUA E ESGOTO (*)             NaN
# 773                                PARSAN S.A. (*) (**)             NaN
# 775                              QUALICORP S/A (*) (**)             NaN
# 777                          RAIA DROGASIL S/A (*) (**)             NaN
# 778                               RAIA DROGASIL S/A (*)             NaN
# 779                               RAIA DROGASIL S/A (*)             NaN
# 784                   RODOVIAS DAS COLINAS S/A (*) (**)             NaN
# 785                   RODOVIAS DAS COLINAS S/A (*) (**)             NaN
# 787                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 788                      REDE DOR SÃO LUIZ S/A (*) (**)             NaN
# 789                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 790                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 791                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 792                      REDE DOR SÃO LUIZ S/A (*) (**)             NaN
# 793                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 794                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 795                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 796                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 797                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 798                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 799                           REDE DOR SÃO LUIZ S/A (*)             NaN
# 802                             PETRORECONCAVO S.A. (*)             NaN
# 803                             LOCALIZA RENT A CAR (*)             NaN
# 804                             LOCALIZA RENT A CAR (*)             NaN
# 805                             LOCALIZA RENT A CAR (*)             NaN
# 806                             LOCALIZA RENT A CAR (*)             NaN
# 807                             LOCALIZA RENT A CAR (*)             NaN
# 808                             LOCALIZA RENT A CAR (*)             NaN
# 814       RGE SUL DISTRIBUIDORA DE ENERGIA S/A (*) (**)             NaN
# 815                     RIO PARANA ENERGIA S/A (*) (**)             NaN
# 826    RANDON S.A. IMPLEMENTOS E PARTICIPACOES (*) (**)             NaN
# 827         RANDON S.A. IMPLEMENTOS E PARTICIPACOES (*)             NaN
# 828         RANDON S.A. IMPLEMENTOS E PARTICIPACOES (*)             NaN
# 829         RANDON S.A. IMPLEMENTOS E PARTICIPACOES (*)             NaN
# 830         RANDON S.A. IMPLEMENTOS E PARTICIPACOES (*)             NaN
# 831                 RODOVIAS DO BRASIL HOLDING S.A. (*)             NaN
# 833                    3R PETROLEUM OLEO E GAS S.A. (*)             NaN
# 834   COMPANHIA RIOGRANDENSE DE SANEAMENTO - CORSAN (*)             NaN
# 836   COMPANHIA RIOGRANDENSE DE SANEAMENTO - CORSAN ...             NaN
# 837   COMPANHIA RIOGRANDENSE DE SANEAMENTO - CORSAN (*)             NaN
# 853             ENERGISA PARAIBA - DISTR.DE ENERGIA S/A             NaN
# 854    ENERGISA PARAIBA - DISTR.DE ENERGIA S/A (*) (**)             NaN
# 857             ENERGISA PARAIBA - DISTR.DE ENERGIA S/A             NaN
# 860   COMPANHIA DE SANEAMENTO DO PARANA - SANEPAR (*...             NaN
# 861   COMPANHIA DE SANEAMENTO DO PARANA - SANEPAR (*...             NaN
# 865     COMPANHIA DE SANEAMENTO DO PARANA - SANEPAR (*)             NaN
# 866     COMPANHIA DE SANEAMENTO DO PARANA - SANEPAR (*)             NaN
# 868            SBF COMERCIO DE PRODUTOS ESPORTIVOS S.A.             NaN
# 869            SBF COMERCIO DE PRODUTOS ESPORTIVOS S.A.             NaN
# 870   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 871   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 873   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 874   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 876   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 879   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 880   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 882   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 883   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 885   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 887   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 888   CIA. DE SANEAMENTO BÁSICO DO ESTADO DE SP - SA...             NaN
# 890                                SIMPAR S.A. (*) (**)             NaN
# 891                                     SIMPAR S.A. (*)             NaN
# 892        SMARTFIT ESCOLA DE GINASTICA E DANCA S/A (*)             NaN
# 893        SMARTFIT ESCOLA DE GINASTICA E DANCA S/A (*)             NaN
# 894        SMARTFIT ESCOLA DE GINASTICA E DANCA S/A (*)             NaN
# 897                       SANEAMENTO DE GOIÁS - SANEAGO             NaN
# 898                       SANEAMENTO DE GOIÁS - SANEAGO             NaN
# 899                       SANEAMENTO DE GOIÁS - SANEAGO             NaN
# 900                       SANEAMENTO DE GOIÁS - SANEAGO             NaN
# 901                       SANEAMENTO DE GOIÁS - SANEAGO             NaN
# 905                     SANTOS BRASIL PARTICIPAÇÕES S/A             NaN
# 906                 SANTOS BRASIL PARTICIPAÇÕES S/A (*)             NaN
# 909                                 SUL AMÉRICA S/A (*)             NaN
# 913                                SUZANO S.A. (*) (**)             NaN
# 917                                     SUZANO S.A. (*)             NaN
# 918                                     SUZANO S.A. (*)             NaN
# 919                   SOLVI ESSENCIS AMBIENTAL S.A. (*)             NaN
# 920                   SOLVI ESSENCIS AMBIENTAL S.A. (*)             NaN
# 922     TRANS. ALIANÇA DE ENERGIA ELÉTRICA S/A (*) (**)             NaN
# 926              TRANS. ALIANÇA DE ENERGIA ELÉTRICA S/A             NaN
# 929   TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A. (*)             NaN
# 932              TRANS. ALIANÇA DE ENERGIA ELÉTRICA S/A             NaN
# 939         TIM BRASIL SERVICOS E PARTICIPACOES S.A (*)             NaN
# 942                        LOCALIZA FLEET S.A. (*) (**)             NaN
# 943                        LOCALIZA FLEET S.A. (*) (**)             NaN
# 944                        LOCALIZA FLEET S.A. (*) (**)             NaN
# 945                             LOCALIZA FLEET S.A. (*)             NaN
# 946                             LOCALIZA FLEET S.A. (*)             NaN
# 947                             LOCALIZA FLEET S.A. (*)             NaN
# 949                      AES TIETE ENERGIA S/A (*) (**)             NaN
# 952                           AES TIETE ENERGIA S/A (*)             NaN
# 953                         TIGRE S.A PARTICIPACOES (*)             NaN
# 955                      TELEFÔNICA BRASIL S/A (*) (**)             NaN
# 962                  TRES TENTOS AGROINDUSTRIAL S.A (*)             NaN
# 964   COMPANHIA DE TRANSMISSÃO DE ENERGIA ELÉTRICA P...             NaN
# 966   COMPANHIA DE TRANSMISSÃO DE ENERGIA ELÉTRICA P...             NaN
# 967   COMPANHIA DE TRANSMISSÃO DE ENERGIA ELÉTRICA P...             NaN
# 970   COMPANHIA DE TRANSMISSÃO DE ENERGIA ELÉTRICA P...             NaN
# 972      TRANSPORTADORA ASSOCIADA DE GAS S.A. - TAG (*)             NaN
# 974                                        TUPY S/A (*)             NaN
# 975                                        TUPY S/A (*)             NaN
# 976                                        TUPY S/A (*)             NaN
# 979                                 UNIDAS S/A (*) (**)             NaN
# 980                                      UNIDAS S/A (*)             NaN
# 981                                 UNIDAS S/A (*) (**)             NaN
# 983                               UNIPAR CARBOCLORO S/A             NaN
# 984                               UNIPAR CARBOCLORO S/A             NaN
# 985                           UNIPAR CARBOCLORO S/A (*)             NaN
# 986                           UNIPAR CARBOCLORO S/A (*)             NaN
# 987                               UNIPAR CARBOCLORO S/A             NaN
# 988                           UNIPAR CARBOCLORO S/A (*)             NaN
# 989                           UNIPAR CARBOCLORO S/A (*)             NaN
# 991         UNIÃO QUÍMICA FARMACÊUTICA NACIONAL S/A (*)             NaN
# 993   USINAS SIDERURGICAS DE MINAS GERAIS S/A - USIM...             NaN
# 994   USINAS SIDERURGICAS DE MINAS GERAIS S/A - USIM...             NaN
# 995   USINAS SIDERURGICAS DE MINAS GERAIS S/A - USIM...             NaN
# 996   USINAS SIDERURGICAS DE MINAS GERAIS S/A - USIM...             NaN
# 997   USINAS SIDERURGICAS DE MINAS GERAIS S/A - USIM...             NaN
# 998   USINAS SIDERURGICAS DE MINAS GERAIS S/A - USIM...             NaN
# 1008  VAMOS LOCACAO DE CAMINHOES, MAQUINAS E EQUIPAM...             NaN
# 1009  VAMOS LOCACAO DE CAMINHOES, MAQUINAS E EQUIPAM...             NaN
# 1010  VAMOS LOCACAO DE CAMINHOES, MAQUINAS E EQUIPAM...             NaN
# 1011  VAMOS LOCACAO DE CAMINHOES, MAQUINAS E EQUIPAM...             NaN
# 1012  VAMOS LOCACAO DE CAMINHOES, MAQUINAS E EQUIPAM...             NaN
# 1013  VAMOS LOCACAO DE CAMINHOES, MAQUINAS E EQUIPAM...             NaN
# 1016  VAMOS LOCACAO DE CAMINHOES, MAQUINAS E EQUIPAM...             NaN
# 1017                              VIBRA ENERGIA S.A (*)             NaN
# 1018                              VIBRA ENERGIA S.A (*)             NaN
# 1019                              VIBRA ENERGIA S.A (*)             NaN
# 1020                              VIBRA ENERGIA S.A (*)             NaN
# 1021                              VIBRA ENERGIA S.A (*)             NaN
# 1022                              VIBRA ENERGIA S.A (*)             NaN
# 1026  VERT-11 COMPANHIA SECURITIZADORA DE CREDITOS F...             NaN
# 1031                                  VIX LOGÍSTICA S/A             NaN
# 1032                                  VIX LOGÍSTICA S/A             NaN
# 1033                              VIX LOGÍSTICA S/A (*)             NaN
# 1034                                  VIX LOGÍSTICA S/A             NaN
# 1035                                  VIX LOGÍSTICA S/A             NaN
# 1036                                  VIX LOGÍSTICA S/A             NaN
# 1037                                  VIX LOGÍSTICA S/A             NaN
# 1038                             VALID SOLUCOES S/A (*)             NaN
# 1043  VRENTAL LOCACAO DE MAQUINAS E EQUIPAMENTOS S.A...             NaN
# 1044  VRENTAL LOCACAO DE MAQUINAS E EQUIPAMENTOS S.A...             NaN
# 1047                        CM HOSPITALAR S.A. (*) (**)             NaN
# 1048                        CM HOSPITALAR S.A. (*) (**)             NaN
# 1050  WIZ SOLUCOES E CORRETAGEM DE SEGUROS S.A. (*) ...             NaN
# 1052                           XP INVESTIMENTOS S/A (*)             NaN
# 1053    INFRAESTRUTURA BRASIL HOLDING XVII S.A (*) (**)             NaN
# 1054                   YDUQS PARTICIPACOES S.A (*) (**)             NaN
# 1055                        YDUQS PARTICIPACOES S.A (*)             NaN

# %%
from sqlalchemy import create_engine, Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# 1. Criar a engine de conexão
DATABASE_URL = "postgresql://usuario:senha@localhost:5432/meu_banco"
engine = create_engine(DATABASE_URL)

# 2. Criar uma base para definir as tabelas
Base = declarative_base()

# 3. Definir o modelo da tabela
class Produto(Base):
    __tablename__ = "produtos"
    id = Column(Integer, primary_key=True, autoincrement=True)
    nome = Column(String, nullable=False)
    preco = Column(Float, nullable=False)
    estoque = Column(Integer, nullable=False)

# 4. Criar a tabela no banco de dados
Base.metadata.create_all(engine)

# 5. Criar uma sessão para interagir com o banco de dados
Session = sessionmaker(bind=engine)
session = Session()

# 6. Inserir dados na tabela
novo_produto = Produto(nome="Notebook", preco=3500.99, estoque=10)
session.add(novo_produto)
session.commit()  # Confirma a transação
print(f"Produto inserido com ID: {novo_produto.id}")

# 7. Consultar dados
produtos = session.query(Produto).all()
for produto in produtos:
    print(f"ID: {produto.id}, Nome: {produto.nome}, Preço: {produto.preco}, Estoque: {produto.estoque}")

# 8. Fechar a sessão
session.close()

# %%
data[0]
# Out:
# {'grupo': 'DI SPREAD',
#  'codigo_ativo': 'AALM12',
#  'data_referencia': '2025-01-20',
#  'data_vencimento': '2030-10-02',
#  'percentual_taxa': 'DI + 1,6000%',
#  'taxa_compra': 1.5537,
#  'taxa_venda': 1.3763,
#  'taxa_indicativa': 1.4778,
#  'desvio_padrao': 0.0,
#  'val_min_intervalo': 1.47,
#  'val_max_intervalo': 1.48,
#  'pu': 1034.821886,
#  'percent_pu_par': 100.37,
#  'duration': 770,
#  'percent_reune': '15%',
#  'data_finalizado': '2025-01-20T19:49:51.933271',
#  'emissor': 'AURA ALMAS MINERACAO S.A. (*)'}

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#print(data[0].keys())

# print(data[0]["data_referencia"])
# print(data[0]["parametros"])
# print(data[0]["erros"])

#print(data[0]["ettj"][i] == 21)
# print(data[0]["bloco3361"])

print(data)
# Out:
# [{'data_referencia': '2025-01-30', 'parametros': [{'grupo_indexador': 'IPCA', 'b1': 0.0727603239370905, 'b2': -0.0743379057638151, 'b3': 0.0834385382294063, 'b4': 0.0105885176901349, 'l1': 2.0739328943548863, 'l2': 0.3549813521629222}, {'grupo_indexador': 'PREFIXADOS', 'b1': 0.1146359503338761, 'b2': 0.0096441305506841, 'b3': 0.0718792181437767, 'b4': 0.098336235186785, 'l1': 1.6831596549673136, 'l2': 0.1789951350516885}], 'erros': [{'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2025-04-01', 'valor_erro': -0.0868}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2025-07-01', 'valor_erro': 0.0614}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2025-10-01', 'valor_erro': 0.0629}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2026-01-01', 'valor_erro': -0.0003}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2026-04-01', 'valor_erro': -0.0605}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2026-07-01', 'valor_erro': -0.0714}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2026-10-01', 'valor_erro': -0.0071}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2027-04-01', 'valor_erro': -0.0268}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2027-07-01', 'valor_erro': 0.0011}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2028-01-01', 'valor_erro': 0.0246}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2028-07-01', 'valor_erro': 0.0331}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2029-01-01', 'valor_erro': -0.0176}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2030-01-01', 'valor_erro': -0.0037}, {'tipo_titulo': '100000', 'codigo_selic': 'LTN', 'data_vencimento': '2032-01-01', 'valor_erro': 0.0039}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2025-05-15', 'valor_erro': 0.3658}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2026-08-15', 'valor_erro': -0.3175}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2027-05-15', 'valor_erro': 0.1712}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2028-08-15', 'valor_erro': 0.0736}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2029-05-15', 'valor_erro': 0.1073}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2030-08-15', 'valor_erro': -0.0071}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2032-08-15', 'valor_erro': -0.0969}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2033-05-15', 'valor_erro': -0.0482}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2035-05-15', 'valor_erro': -0.0512}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2040-08-15', 'valor_erro': 0.1149}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2045-05-15', 'valor_erro': -0.0009}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2050-08-15', 'valor_erro': -0.0195}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2055-05-15', 'valor_erro': -0.0008}, {'tipo_titulo': '760199', 'codigo_selic': 'NTN-B', 'data_vencimento': '2060-08-15', 'valor_erro': -0.0129}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2027-01-01', 'valor_erro': 0.0679}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2029-01-01', 'valor_erro': -0.0026}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2031-01-01', 'valor_erro': -0.0442}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2033-01-01', 'valor_erro': 0.0586}, {'tipo_titulo': '950199', 'codigo_selic': 'NTN-F', 'data_vencimento': '2035-01-01', 'valor_erro': -0.0277}], 'ettj': [{'vertice_du': 21, 'taxa_prefi ...

# %%
pd.set_option('display.max_rows', None)
dados = pd.DataFrame(data[0]['ettj'])

# %%
dados = dados.dropna()
for index, row in dados.iterrows():
    print(row['vertice_du']/252, row['taxa_prefixadas'], row['taxa_ipca'], row['taxa_implicita'])
# Out:
# 0.5 14.2916 4.9679 8.8824
# 1.0 14.8535 6.7598 7.5812
# 1.5 14.9644 7.3829 7.0602
# 2.0 14.9451 7.5977 6.8285
# 2.5 14.9071 7.6698 6.7217
# 3.0 14.8825 7.6919 6.677
# 3.5 14.8752 7.6959 6.6662
# 4.0 14.8809 7.6931 6.6743
# 4.5 14.894 7.6871 6.6924
# 5.0 14.9101 7.6795 6.7149
# 5.5 14.9258 7.6707 6.7382
# 6.0 14.9389 7.6613 6.7597
# 6.5 14.9481 7.6513 6.7781
# 7.0 14.9527 7.641 6.7926
# 7.5 14.9525 7.6306 6.8028
# 8.0 14.9474 7.62 6.8085
# 8.5 14.9375 7.6095 6.8098
# 9.0 14.9232 7.5992 6.8067
# 9.5 14.9047 7.5891 6.7995
